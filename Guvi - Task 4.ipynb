# %% [markdown]
# # import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
d1 = pd.read_csv('D:\Guvi Task 4 csv files/college_1.csv')
d1
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 79    KarthikeyanS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 82    mohamed nabi     0.0    0.0                  0               0
# 83  yaser ahamed.A     0.0   27.0                  0               0
#
#                                 Department  Rising
# 0         Computer Science and Engineering       0
# ...

# %%
df1 = pd.DataFrame(d1)
df1
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 79    KarthikeyanS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 82    mohamed nabi     0.0    0.0                  0               0
# 83  yaser ahamed.A     0.0   27.0                  0               0
#
#                                 Department  Rising
# 0         Computer Science and Engineering       0
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               84 non-null     object
#  1   python             84 non-null     float64
#  2   mysql              84 non-null     float64
#  3   Previous Geekions  84 non-null     int64
#  4   CodeKata Score     84 non-null     int64
#  5   Department         84 non-null     object
#  6   Rising             84 non-null     int64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 4.7+ KB

# %%
df1.describe()
# Out:
#            python      mysql  Previous Geekions  CodeKata Score      Rising
# count   84.000000   84.00000          84.000000       84.000000   84.000000
# mean    73.392857   27.60119        2904.523810     2906.071429    1.547619
# std     35.589280   36.30562        4372.425826     4374.184197   14.184163
# min      0.000000    0.00000           0.000000        0.000000    0.000000
# 25%     52.250000    0.00000         292.500000      292.500000    0.000000
# 50%     90.250000   11.62500        1580.000000     1580.000000    0.000000
# 75%    100.000000   41.00000        3727.500000     3727.500000    0.000000
# max    100.000000  100.00000       24500.000000    24500.000000  130.000000

# %%
d2 = pd.read_csv('D:\Guvi Task 4 csv files/college_2.csv')
d2
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0            ASHOK KUMAR K     100          0     31                       9
# 1                  Chandru       0         20      0                       0
# 2        Ganesh Ramkumar R      -1         55     24                       6
# 3          Bodipudi Harini      -1          0     35                      -1
# 4                VIINU V P      -1        100     24                      -1
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 7                Gowtham R      -1         60      4                       6
# 8                 shifak N      58          0      0                       0
# 9                  Balaji       -1        100     20                       0
# 10                Rushitha      -1         15     62                       9
# ...

# %%
df2 = pd.DataFrame(d2)
df2
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0            ASHOK KUMAR K     100          0     31                       9
# 1                  Chandru       0         20      0                       0
# 2        Ganesh Ramkumar R      -1         55     24                       6
# 3          Bodipudi Harini      -1          0     35                      -1
# 4                VIINU V P      -1        100     24                      -1
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 7                Gowtham R      -1         60      4                       6
# 8                 shifak N      58          0      0                       0
# 9                  Balaji       -1        100     20                       0
# 10                Rushitha      -1         15     62                       9
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    35 non-null     object
#  1   python                  35 non-null     int64
#  2   python_en               35 non-null     int64
#  3   mysql                   35 non-null     int64
#  4   computational_thinking  35 non-null     int64
#  5   Previous Geekions       35 non-null     int64
#  6   CodeKata Score          35 non-null     int64
#  7   Department              35 non-null     object
#  8   Rising                  35 non-null     int64
# dtypes: int64(7), object(2)
# memory usage: 2.6+ KB

# %%
df2.describe()
# Out:
#            python   python_en       mysql  computational_thinking  \
# count   35.000000   35.000000   35.000000               35.000000
# mean     8.657143   29.657143   13.657143                2.200000
# std     25.795511   30.582524   22.002597                7.015948
# min     -1.000000   -1.000000   -1.000000               -1.000000
# 25%     -1.000000    0.000000    0.000000                0.000000
# 50%     -1.000000   20.000000    0.000000                0.000000
# 75%     -1.000000   52.000000   24.000000                0.000000
# max    100.000000  100.000000  100.000000               39.000000
#
#        Previous Geekions  CodeKata Score       Rising
# count          35.000000       35.000000    35.000000
# mean         6093.142857     6801.428571   708.285714
# std          3650.436534     3765.281134   836.429687
# min             0.000000        0.000000     0.000000
# 25%          4035.000000     4630.000000     0.000000
# ...

# %% [markdown]
# # merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
df = pd.concat([df1,df2],ignore_index=True)
df
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 114  praveen raj j    24.0    0.0               2380            2380
# 115     AMARNATH D    -1.0   12.0               1890            1890
# 116           bala    32.0    0.0               1720            1720
# 117           XY Z    -1.0   -1.0                  0               0
# 118      Hariharan    -1.0   -1.0                  0               0
#
#                                     Department  Rising  python_en  \
# 0             Computer Science and Engineering       0        NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    119 non-null    object
#  1   python                  119 non-null    float64
#  2   mysql                   119 non-null    float64
#  3   Previous Geekions       119 non-null    int64
#  4   CodeKata Score          119 non-null    int64
#  5   Department              119 non-null    object
#  6   Rising                  119 non-null    int64
#  7   python_en               35 non-null     float64
#  8   computational_thinking  35 non-null     float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 8.5+ KB

# %%
df.describe()
# Out:
#            python       mysql  Previous Geekions  CodeKata Score       Rising  \
# count  119.000000  119.000000         119.000000      119.000000   119.000000
# mean    54.352941   23.500000        3842.352941     4051.764706   209.411765
# std     44.272526   33.276671        4406.339992     4551.951881   553.445746
# min     -1.000000   -1.000000           0.000000        0.000000     0.000000
# 25%      0.000000    0.000000         740.000000      740.000000     0.000000
# 50%     82.000000    4.000000        2410.000000     2410.000000     0.000000
# 75%    100.000000   33.000000        5340.000000     5975.000000     0.000000
# max    100.000000  100.000000       24500.000000    24500.000000  3140.000000
#
#         python_en  computational_thinking
# count   35.000000               35.000000
# mean    29.657143                2.200000
# std     30.582524                7.015948
# min     -1.000000               -1.000000
# 25%      0.000000                0.000000
# ...

# %%
df.to_csv('merged college 1&2.csv') # you can find the new merged college 1&2 file in your local

# %% [markdown]
# Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)
# consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv
# if 10000<codekata score<15000 (Reached_expectations.csv)
# if 7000<codekata score<10000 (Needs_Improvement.csv)
# if codekate score < 7000 (Unsatisfactory.csv)

# %% [markdown]
# # if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %%
exceeded_expectations = df[df['CodeKata Score']>15000]
exceeded_expectations.to_csv('exceeded_expectations.csv') # you can find the new exceeded_expectations.csv file in your local
exceeded_expectations
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 84  ASHOK KUMAR K   100.0   31.0              19400           19400
#
#                                 Department  Rising  python_en  \
# 0         Computer Science and Engineering       0        NaN
# 1         Computer Science and Engineering       0        NaN
# 2         Computer Science and Engineering       0        NaN
# 84  Electronics and Electrical Engineering       0        0.0
#
#     computational_thinking
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 84                     9.0

# %% [markdown]
# # if 10000<codekata score<15000 (Reached_expectations.csv)

# %%
reached_expectations = df[(df['CodeKata Score']>10000) & (df['CodeKata Score']<15000)]
reached_expectations.to_csv('reached_expectations.csv') # you can find the new reached_expectations.csv file in your local
reached_expectations
# Out:
#                  Name  python  mysql  Previous Geekions  CodeKata Score  \
# 3         Mugunthan S   100.0   47.0              10610           10610
# 85            Chandru     0.0    0.0              14150           14490
# 86  Ganesh Ramkumar R    -1.0   24.0               8790           10790
# 87    Bodipudi Harini    -1.0   35.0              10040           10040
#
#                                    Department  Rising  python_en  \
# 3            Computer Science and Engineering       0        NaN
# 85           Computer Science and Engineering     340       20.0
# 86           Computer Science and Engineering    2000       55.0
# 87  Electronics and Communication Engineering       0        0.0
#
#     computational_thinking
# 3                      NaN
# 85                     0.0
# 86                     6.0
# 87                    -1.0

# %% [markdown]
# # if 7000<codekata score<10000 (Needs_Improvement.csv)

# %%
needs_improvement = df[(df['CodeKata Score']>7000) & (df['CodeKata Score']<10000)]
needs_improvement.to_csv('needs_improvement.csv') # you can find the new needs_improvement.csv file in your local
needs_improvement
# Out:
#                        Name  python  mysql  Previous Geekions  CodeKata Score  \
# 4               Sathammai.S   100.0    8.0               8980            8980
# 5              NIVEESHWAR S   100.0    0.0               8200            8200
# 6             KALAIARASAN K    85.0   47.0               7750            7880
# 7      MOHAMED ZUBAIR AHMED    82.0    4.0               7020            7020
# 88                VIINU V P    -1.0   24.0               9150            9150
# 89               Poojitha Y     0.0   35.0               7210            8970
# 90   Gowtham Chandrasekaran    -1.0    0.0               7250            8950
# 91                Gowtham R    -1.0    4.0               8650            8650
# 92                 shifak N    58.0    0.0               5180            8320
# 93                  Balaji     -1.0   20.0               6170            8160
# 94                 Rushitha    -1.0   62.0               7470            8090
# ...

# %% [markdown]
# # if codekate score < 7000 (Unsatisfactory.csv)

# %%
unsatisfactory = df[df['CodeKata Score']<7000]
unsatisfactory.to_csv('unsatisfactory.csv') # you can find the new unsatisfactory.csv file in your local
unsatisfactory
# Out:
#                 Name  python  mysql  Previous Geekions  CodeKata Score  \
# 8         J.SUGANTHI    27.0  50.00               5860            5860
# 9       thamizhpaana    29.0   0.00               5500            5500
# 10   Iyappan Samiraj    50.0  24.00               5400            5400
# 11      Ponniyamma.R   100.0  11.25               5380            5380
# 12         SABAPATHI   100.0   0.00               5280            5280
# ..               ...     ...    ...                ...             ...
# 114    praveen raj j    24.0   0.00               2380            2380
# 115       AMARNATH D    -1.0  12.00               1890            1890
# 116             bala    32.0   0.00               1720            1720
# 117             XY Z    -1.0  -1.00                  0               0
# 118        Hariharan    -1.0  -1.00                  0               0
#
#                                     Department  Rising  python_en  \
# ...

# %% [markdown]
# # Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
avg_preGK = df['Previous Geekions'].mean()
print('Average of previous week geekions is',avg_preGK)
avg_CK = df['CodeKata Score'].mean()
print('Average of CodeKata Score is',avg_CK)
# Out:
# Average of previous week geekions is 3842.3529411764707
# Average of CodeKata Score is 4051.764705882353

# %% [markdown]
# # No of students participated

# %%
no_of_students = df['Name'].count()
print('No.of.Students Participated is',no_of_students)
# Out:
# No.of.Students Participated is 119

# %% [markdown]
# # Average completion of python course or my_sql or python english or computational thinking

# %%
Avg = df['python'].mean()
print('Average completion of python course is',Avg)
# Out:
# Average completion of python course is 54.35294117647059

# %% [markdown]
# # rising star of the week (top 3 candidate who performed well in that particular week)

# %%
rising_star = df.sort_values(by = ['Rising'],ascending = False).head(3)
rising_star
# Out:
#                   Name  python  mysql  Previous Geekions  CodeKata Score  \
# 92            shifak N    58.0    0.0               5180            8320
# 102     Narasimhan Y L    -1.0    0.0               4800            6800
# 86   Ganesh Ramkumar R    -1.0   24.0               8790           10790
#
#                                  Department  Rising  python_en  \
# 92   Electronics and Electrical Engineering    3140        0.0
# 102        Computer Science and Engineering    2000       -1.0
# 86         Computer Science and Engineering    2000       55.0
#
#      computational_thinking
# 92                      0.0
# 102                     0.0
# 86                      6.0

# %% [markdown]
# # Shining stars of the week (top 3 candidates who has highest geekions)

# %%
shining_star = df.sort_values(by = ['Previous Geekions'],ascending = False).head(3)
shining_star
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# # Department wise codekata performence (pie chart)

# %%
import plotly.express as px

# %%
fig = px.pie(df,values ="CodeKata Score",names="Department",title='DEPARTMENT WISE CODEKATA PERFORMANCE')
fig.show()
# Out:
# <div>                            <div id="51d819a4-9336-4309-87ac-7c45f89b03a5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("51d819a4-9336-4309-87ac-7c45f89b03a5")) {                    Plotly.newPlot(                        "51d819a4-9336-4309-87ac-7c45f89b03a5",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Department=%{label}<br>CodeKata Score=%{value}<extra></extra>","labels":["Computer Science and Engineering","Computer Science and Engineering","Computer Science and Engineering","Computer Science and Engineering","Computer Science and Engineering","Computer Science and Engineering","Electronics and Communication Engineering","Computer Science and Engineering","Electronics and Communication Engineering","Com
# ...

# %% [markdown]
# # Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
df['Department'].describe()
# Out:
# count                                  119
# unique                                   3
# top       Computer Science and Engineering
# freq                                    63
# Name: Department, dtype: object

# %%
x = (df['Department'].unique())
x
# Out:
# array(['Computer Science and Engineering',
#        'Electronics and Communication Engineering',
#        'Electronics and Electrical Engineering'], dtype=object)

# %%
a=df[df['Department']=='Computer Science and Engineering']
a1=a['CodeKata Score'].sum()
a1
# Out:
# 320025

# %%
b=df[df['Department']=='Electronics and Communication Engineering']
b1=b['CodeKata Score'].sum()
b1
# Out:
# 108335

# %%
c=df[df['Department']=='Electronics and Electrical Engineering']
c1=c['CodeKata Score'].sum()
c1
# Out:
# 53800

# %%
x=a[a['CodeKata Score']==a['CodeKata Score'].max()]
x
# Out:
#         Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0  A.Dharani    82.0   20.0              24500           24500
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN

# %%
y=b[b['CodeKata Score']==b['CodeKata Score'].max()]
y
# Out:
#                Name  python  mysql  Previous Geekions  CodeKata Score  \
# 87  Bodipudi Harini    -1.0   35.0              10040           10040
#
#                                    Department  Rising  python_en  \
# 87  Electronics and Communication Engineering       0        0.0
#
#     computational_thinking
# 87                    -1.0

# %%
z=c[c['CodeKata Score']==c['CodeKata Score'].max()]
z
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 84  ASHOK KUMAR K   100.0   31.0              19400           19400
#
#                                 Department  Rising  python_en  \
# 84  Electronics and Electrical Engineering       0        0.0
#
#     computational_thinking
# 84                     9.0

# %%
X=['A.Dharani-CSE','Bodipudi Harini-ECE','Ashok Kumar K-EEE']
Y=[24500,10040,19400]
plt.bar(X,Y)

plt.xlabel('DEPARTMENT WISE TOPPERS')
plt.ylabel('CODEKATA SCORE')
plt.title('VERTICAL BAR GRAPH')

plt.show()
